# %% [markdown]
# # Pandas Data Frames
# -----

# %%
import pandas as pd

read_demo = pd.read_excel("C:/Users/Doctor/Desktop/BigDataWork/datasets/demo.xlsx")

read_demo
# Out:
#      Policy      Expiry Location State     Region  InsuredValue Construction  \
# 0    100242    1/2/2021    Urban    NY       East       1617630        Frame
# 1    100314    1/2/2021    Urban    NY       East       8678500  Fire Resist
# 2    100359    1/2/2021    Rural    WI    Midwest       2052660        Frame
# 3    100315    1/3/2021    Urban    NY       East      17580000        Frame
# 4    100385    1/3/2021    Urban    NY       East       1925000      Masonry
# ..      ...         ...      ...   ...        ...           ...          ...
# 495  101121  12/31/2021    Urban    VT  Northeast       4101750  Fire Resist
# 496  101122  12/31/2021    Urban    OH    Central       1739100        Frame
# 497  101123  12/31/2021    Urban    NY       East       2250000        Frame
# 498  101125  12/31/2021    Urban    NY       East      16482200        Frame
# 499  101126  12/31/2021    Urban    WI    Midwest       1776800        Frame
#
#     BusinessType Earthquake Flood
# ...

# %%
# checking data information
read_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Policy        500 non-null    int64
#  1   Expiry        500 non-null    object
#  2   Location      500 non-null    object
#  3   State         500 non-null    object
#  4   Region        500 non-null    object
#  5   InsuredValue  500 non-null    int64
#  6   Construction  500 non-null    object
#  7   BusinessType  500 non-null    object
#  8   Earthquake    500 non-null    object
#  9   Flood         500 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 39.2+ KB

# %%
# checking the data shape <dimension on the table (#No. of Rows, #No. of columns) >
read_demo.shape
# Out:
# (500, 10)

# %%
# show first 5 records in the dataframe
read_demo.head()
# Out:
#    Policy    Expiry Location State   Region  InsuredValue Construction  \
# 0  100242  1/2/2021    Urban    NY     East       1617630        Frame
# 1  100314  1/2/2021    Urban    NY     East       8678500  Fire Resist
# 2  100359  1/2/2021    Rural    WI  Midwest       2052660        Frame
# 3  100315  1/3/2021    Urban    NY     East      17580000        Frame
# 4  100385  1/3/2021    Urban    NY     East       1925000      Masonry
#
#   BusinessType Earthquake Flood
# 0       Retail          N     N
# 1    Apartment          Y     Y
# 2      Farming          N     N
# 3    Apartment          Y     Y
# 4  Hospitality          N     N

# %%
# show last 5 records in the dataframe
read_demo.tail()
# Out:
#      Policy      Expiry Location State     Region  InsuredValue Construction  \
# 495  101121  12/31/2021    Urban    VT  Northeast       4101750  Fire Resist
# 496  101122  12/31/2021    Urban    OH    Central       1739100        Frame
# 497  101123  12/31/2021    Urban    NY       East       2250000        Frame
# 498  101125  12/31/2021    Urban    NY       East      16482200        Frame
# 499  101126  12/31/2021    Urban    WI    Midwest       1776800        Frame
#
#     BusinessType Earthquake Flood
# 495  Office Bldg          Y     Y
# 496    Apartment          N     N
# 497  Office Bldg          Y     Y
# 498  Office Bldg          Y     Y
# 499      Farming          N     N

# %%
# Summary of all the `numeric` columns in the dataset
read_demo.describe()
# Out:
#               Policy  InsuredValue
# count     500.000000  5.000000e+02
# mean   100656.020000  4.964411e+06
# std       274.861014  6.205834e+06
# min    100200.000000  3.000000e+04
# 25%    100411.750000  1.603600e+06
# 50%    100652.500000  2.593682e+06
# 75%    100894.250000  6.005692e+06
# max    101126.000000  5.341061e+07

# %%
# Check Columns name
read_demo.columns
# Out:
# Index(['Policy', 'Expiry', 'Location', 'State', 'Region', 'InsuredValue',
#        'Construction', 'BusinessType', 'Earthquake', 'Flood'],
#       dtype='object')

# %%
# Extract the values of a dataframe as a `numpy` array using `dataframe.values`

read_demo.values
# Out:
# array([[100242, '1/2/2021', 'Urban', ..., 'Retail', 'N', 'N'],
#        [100314, '1/2/2021', 'Urban', ..., 'Apartment', 'Y', 'Y'],
#        [100359, '1/2/2021', 'Rural', ..., 'Farming', 'N', 'N'],
#        ...,
#        [101123, '12/31/2021', 'Urban', ..., 'Office Bldg', 'Y', 'Y'],
#        [101125, '12/31/2021', 'Urban', ..., 'Office Bldg', 'Y', 'Y'],
#        [101126, '12/31/2021', 'Urban', ..., 'Farming', 'N', 'N']],
#       dtype=object)

# %%
# if you want to change the index with a column

read_demo.set_index('Policy', inplace=True)

read_demo.head()
# Out:
#           Expiry Location State   Region  InsuredValue Construction  \
# Policy
# 100242  1/2/2021    Urban    NY     East       1617630        Frame
# 100314  1/2/2021    Urban    NY     East       8678500  Fire Resist
# 100359  1/2/2021    Rural    WI  Midwest       2052660        Frame
# 100315  1/3/2021    Urban    NY     East      17580000        Frame
# 100385  1/3/2021    Urban    NY     East       1925000      Masonry
#
#        BusinessType Earthquake Flood
# Policy
# 100242       Retail          N     N
# 100314    Apartment          Y     Y
# 100359      Farming          N     N
# 100315    Apartment          Y     Y
# 100385  Hospitality          N     N

# %%
# To reset everthing
read_demo.reset_index(inplace=True)

# %%
#  Selecting Rows `Slicing`

read_demo[0:3]
# Out:
#    Policy    Expiry Location State   Region  InsuredValue Construction  \
# 0  100242  1/2/2021    Urban    NY     East       1617630        Frame
# 1  100314  1/2/2021    Urban    NY     East       8678500  Fire Resist
# 2  100359  1/2/2021    Rural    WI  Midwest       2052660        Frame
#
#   BusinessType Earthquake Flood
# 0       Retail          N     N
# 1    Apartment          Y     Y
# 2      Farming          N     N

# %%
# Selecting a column
read_demo['Policy'].head()
# Out:
# 0    100242
# 1    100314
# 2    100359
# 3    100315
# 4    100385
# Name: Policy, dtype: int64

# %%
# Selecting a No. of columns
read_demo[['Policy', 'Region']].head()
# Out:
#    Policy   Region
# 0  100242     East
# 1  100314     East
# 2  100359  Midwest
# 3  100315     East
# 4  100385     East

# %%
# Selecting a column `Slicing`
read_demo.loc[:, "Policy":'Region'].head()
# Out:
#    Policy    Expiry Location State   Region
# 0  100242  1/2/2021    Urban    NY     East
# 1  100314  1/2/2021    Urban    NY     East
# 2  100359  1/2/2021    Rural    WI  Midwest
# 3  100315  1/3/2021    Urban    NY     East
# 4  100385  1/3/2021    Urban    NY     East

# %% [markdown]
# ---
# ## Indexing in Dataframe
# ---

# %%
read_demo.loc[:,'Policy':'State'].head()
# Out:
#    Policy    Expiry Location State
# 0  100242  1/2/2021    Urban    NY
# 1  100314  1/2/2021    Urban    NY
# 2  100359  1/2/2021    Rural    WI
# 3  100315  1/3/2021    Urban    NY
# 4  100385  1/3/2021    Urban    NY

# %%
read_demo.iloc[0, 4]   # get a single value
# Out:
# 'East'

# %%
read_demo.loc[0, 'Region']
# Out:
# 'East'

# %%
read_demo.iloc[0:5,0:3]
# Out:
#    Policy    Expiry Location
# 0  100242  1/2/2021    Urban
# 1  100314  1/2/2021    Urban
# 2  100359  1/2/2021    Rural
# 3  100315  1/3/2021    Urban
# 4  100385  1/3/2021    Urban

# %% [markdown]
# ### Conditional Subsetting

# %%
read_demo["State"] == 'NY'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 495    False
# 496    False
# 497     True
# 498     True
# 499    False
# Name: State, Length: 500, dtype: bool

# %%
read_demo[(read_demo['State']=='NY')].head()
# Out:
#    Policy    Expiry Location State Region  InsuredValue Construction  \
# 0  100242  1/2/2021    Urban    NY   East       1617630        Frame
# 1  100314  1/2/2021    Urban    NY   East       8678500  Fire Resist
# 3  100315  1/3/2021    Urban    NY   East      17580000        Frame
# 4  100385  1/3/2021    Urban    NY   East       1925000      Masonry
# 7  100264  1/7/2021    Rural    NY   East       2219900        Frame
#
#   BusinessType Earthquake Flood
# 0       Retail          N     N
# 1    Apartment          Y     Y
# 3    Apartment          Y     Y
# 4  Hospitality          N     N
# 7      Farming          N     N

# %%
subset = read_demo.loc[(read_demo['State']=='NY'), :'State'].head()
subset
# Out:
#    Policy    Expiry Location State
# 0  100242  1/2/2021    Urban    NY
# 1  100314  1/2/2021    Urban    NY
# 3  100315  1/3/2021    Urban    NY
# 4  100385  1/3/2021    Urban    NY
# 7  100264  1/7/2021    Rural    NY

# %%
subset.isin(read_demo)
# Out:
#    Policy  Expiry  Location  State
# 0    True    True      True   True
# 1    True    True      True   True
# 3    True    True      True   True
# 4    True    True      True   True
# 7    True    True      True   True
